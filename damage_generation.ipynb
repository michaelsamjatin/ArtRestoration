# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi
import cv2
import skimage.exposure
from numpy.random import default_rng
import os
import random

# %%
import matplotlib.pyplot as plt

# Set default color map and interpolation method for images.
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['image.interpolation'] = 'nearest'

# %matplotlib inline

# %%
# Load and resize images
base_directory = "initial"
image_extensions = {".jpg", ".jpeg", ".png"}  # Supported extensions

# Collect all image file paths
all_images = []
for root, _, files in os.walk(base_directory):
    for file in files:
        if os.path.splitext(file)[1].lower() in image_extensions:
            all_images.append(os.path.join(root, file))

random.shuffle(all_images)

#Load the selected images using OpenCV
loaded_images = []
resized_images = [] 

for image_path in all_images:
    img = cv2.imread(image_path)  # Load the image
    if np.all(img[:, :, 0] == img[:, :, 1]) and np.all(img[:, :, 1] == img[:, :, 2]):
        pass #filter out grayscale images
    else:
        # Resize the image to 512x512 using cubic interpolation
        resized_img = cv2.resize(img, (512, 512), interpolation=cv2.INTER_CUBIC)
        resized_images.append(resized_img)
        loaded_images.append(img)

# %%
#write the resize images into a new folder "paintings, with the names 0.jpg to max_number.jpg
for i in range(len(resized_images)):
    cv2.imwrite("paintings/"+str(i)+".jpg",resized_images[i])

# %%
#helper function
def display(figsize, images):
    """
    Display one or more images in a single figure.

    Parameters:
        - figsize: Size of the figure with (width, height).
        - images: List of tuples with (image, title, position).
    """
    plt.figure(figsize=figsize)

    for image, title, position in images:
        plt.subplot(*position if isinstance(position, tuple) else [position])
        plt.title(title)
        plt.axis('off')
        plt.imshow(image)

    plt.show()

# %%
#helper function for crack generation
def add_curvature(p1, p2, n_points=20, curve_intensity=10):
    """
    Adds curvature to a straight line between two points.
    - p1, p2: Endpoints of the line.
    - n_points: Number of intermediate points along the line.
    - curve_intensity: Amplitude of the random curvature.
    """
    # Generate a straight line
    x = np.linspace(p1[0], p2[0], n_points)
    y = np.linspace(p1[1], p2[1], n_points)
    
    # Add curvature using a sinusoidal or random perturbation
    mid_idx = n_points // 2
    for i in range(n_points):
        factor = np.sin((i - mid_idx) / n_points * np.pi)  # Sinusoidal factor for smooth curves
        x[i] += np.random.uniform(-curve_intensity, curve_intensity) * factor
        y[i] += np.random.uniform(-curve_intensity, curve_intensity) * factor

    return np.array([x, y]).T

# %%
#Creats a crack-like pattern using voronoi algorithm and adds curvature using the helper function
def generate_voronoi_cracks(width, height, num_points, line_thickness, curve_intensity, output_path):
    """
    Generates a crack-like pattern using Voronoi diagrams with curved edges and saves it as an image.
    - width, height: Dimensions of the canvas in pixels.
    - num_points: Number of random seed points.
    - line_thickness: Thickness of crack lines.
    - curve_intensity: Degree of curvature added to lines.
    - output_path: Path where the image will be saved.
    """
    # Initialize blank canvas
    canvas = np.ones((height, width, 4), dtype=np.uint8) * 255  # (height, width, 4 channels, white background)
    canvas[:, :, 3] = 0  # Set the alpha channel to 0 (transparent)
    
    # Generate random points
    points = np.random.rand(num_points, 2) * [width, height]
    
    # Create the Voronoi diagram
    vor = Voronoi(points)
    
    for ridge in vor.ridge_vertices:
        if -1 not in ridge:  # Ignore infinite ridges
            # Original line endpoints
            p1, p2 = vor.vertices[ridge]
            
            # Add curvature to the line
            curved_line = add_curvature(p1, p2, n_points=10, curve_intensity=curve_intensity)
            
            # Draw the curved crack on the canvas
            for i in range(len(curved_line) - 1):
                start = tuple(curved_line[i].astype(int))
                end = tuple(curved_line[i + 1].astype(int))
                cv2.line(canvas, start, end, color=(0, 0, 0,255), thickness=line_thickness)
    
    # Save the result
    cv2.imwrite(output_path, canvas)
    print(f"Crack pattern saved to {output_path}")
    return canvas

# %%
#Creats simple scratches
def generate_scratches(mask, overlay):
    height, width = mask.shape[:2]
    num_scratches= np.random.randint(1,6)
    
    colors = [(33, 67, 101),(0,0,0),(255,255,255)]
    
    for _ in range(num_scratches):
        base_color = colors[np.random.randint(len(colors))]
        alpha = np.random.randint(20,100)
        color = (*base_color, alpha)
        # Start at a random position
        x, y = np.random.randint(0, width), np.random.randint(0, height)
        num_segments = np.random.randint(1, 4)  # Number of segments per scratch
        thickness = np.random.randint(1, 6)  # Random line thickness
        
        # Generate a wavy path for the scratch
        for _ in range(num_segments):
            # Slightly vary the direction of the line
            x_offset = np.random.randint(-50, 50)
            y_offset = np.random.randint(-50, 50)
            x_new = np.clip(x + x_offset, 0, width - 1)
            y_new = np.clip(y + y_offset, 0, height - 1)
            
            # Draw on the mask (grayscale for damage detection)
            cv2.line(mask, (x, y), (x_new, y_new), 255, thickness)  # White line for the mask
            
            # Draw on the transparent overlay (colored scratch)
            cv2.line(overlay, (x, y), (x_new, y_new), color, thickness)  # Colored line for visual
        
            # Update the current position
            x, y = x_new, y_new
    
    return mask, overlay

# %%
#Creates rough vertical scratches/gekritzel
def generate_rough_scratches(mask,overlay):
    height, width = mask.shape[:2]
    colors = [(0, 0, 0), (255,255,255)]
    num_scratches = np.random.randint(1,2)
    for _ in range(num_scratches):
        
        base_color = colors[np.random.randint(len(colors))]
        alpha = np.random.randint(20,100)
        color = (*base_color, alpha)
        x, y = np.random.randint(0, width), np.random.randint(0, height)
        num_segments = np.random.randint(1, 3)  # Number of segments per scratch
        thickness = np.random.randint(10, 15)  # Approximate thickness
        
        for _ in range(num_segments):
            
            length = np.random.randint(30, 100)
            points = []
            for i in range(length):
                # Create points along the length of the scratch with random offsets
                x_offset = np.random.randint(-thickness // 2, thickness // 2)
                y_offset = i - length // 2
                points.append((x + x_offset, y + y_offset))
            
            # Convert points to a contour (polygon)
            points = np.array(points, dtype=np.int32)
            points = points.reshape((-1, 1, 2))  # Required format for cv2.drawContours
            
            # Draw the rough scratch as a filled polygon
            cv2.drawContours(mask, [points], -1, 255, -1)
            cv2.drawContours(overlay, [points], -1, color, -1)
            # Slightly move the starting point for the next segment
            x += np.random.randint(-50, 50)
            y += np.random.randint(-50, 50)
            
            # Clip to canvas boundaries
            x = np.clip(x, 0, width - 1)
            y = np.clip(y, 0, height - 1)
            
    return mask, overlay

# %%
#creats rough horizontal scratches/gekritzel
def generate_horizontal_damage(mask,overlay):
    height, width = mask.shape[:2]
    colors = [(0, 0, 0), (255,255,255)]
    num_damages = np.random.randint(1,3)
    for _ in range(num_damages):
        # Choose a random color
        base_color = colors[np.random.randint(len(colors))]
        alpha = np.random.randint(20,100)
        color = (*base_color, alpha)
        
        # Start at a random position
        x, y = np.random.randint(0, width), np.random.randint(0, height)
        num_segments = np.random.randint(1, 3)  # Number of segments per damage
        thickness = np.random.randint(10, 15)  # Approximate thickness
        
        for _ in range(num_segments):
            # Generate a rough contour for the horizontal damage
            length = np.random.randint(50, 150)
            points = []
            for i in range(length):
                # Create points along the width with random vertical offsets
                x_offset = i - length // 2
                y_offset = np.random.randint(-thickness // 2, thickness // 2)
                points.append((x + x_offset, y + y_offset))
            
            points = np.array(points, dtype=np.int32)
            points = points.reshape((-1, 1, 2))  # Required format for cv2.drawContours
            
            # Draw the rough damage as a filled polygon
            cv2.drawContours(mask, [points], -1, 255, -1)
            cv2.drawContours(overlay, [points], -1, color, -1)
            
            # Slightly move the starting point for the next segment
            x += np.random.randint(-50, 50)
            y += np.random.randint(-30, 30)
            
            # Clip to canvas boundaries
            x = np.clip(x, 0, width - 1)
            y = np.clip(y, 0, height - 1)
            
    return mask, overlay

# %%
#creats abrasions.
def generate_abrasions(mask, overlay):
    seedval = np.random.randint(1,100)
    rng = default_rng(seed=seedval)
    
    # define image size
    height, width = mask.shape[:2]
    
    # create random noise image
    noise = rng.integers(0, 255, (height,width), np.uint8, True)
    
    # blur the noise image to control the size
    blur = cv2.GaussianBlur(noise, (0,0), sigmaX=10, sigmaY=10, borderType = cv2.BORDER_DEFAULT)
    
    # stretch the blurred image to full dynamic range
    stretch = skimage.exposure.rescale_intensity(blur, in_range='image', out_range=(0,255)).astype(np.uint8)
    
    # threshold stretched image to control the size
    thresh = cv2.threshold(stretch, 200, 255, cv2.THRESH_BINARY)[1]
    
    # apply morphology open and close to smooth out shapes
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (9,9))
    result = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)
    result = cv2.morphologyEx(result, cv2.MORPH_CLOSE, kernel)
    mask[result ==255] = 255
    colors = [(0,0,0,255),(255,255,255,255)]
    color = colors[np.random.randint(len(colors))]
    overlay[result == 255] = color
    return mask, overlay

# %%
#function to load images from folder
def load_images(folder_path,grayscale=False):
    """
    Load all images from a flat folder without resizing.
    
    Args:
        folder_path (str): Path to the dataset folder containing .jpg images.
    
    Returns:
        list: List of images as NumPy arrays.
    """
    images = []
    image_names = []  # Optional: Store file paths for reference

    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Check for valid image extensions
        # Load the image
        if grayscale:
            image = cv2.imread(file_path,cv2.IMREAD_GRAYSCALE)
        else:
            image = cv2.imread(file_path)
        if image is not None:
            images.append(image)
            image_names.append(file_name)  # Optional: Track file paths
        else:
            print(f"Failed to load image: {file_path}")
            os.remove(file_path)

    print(f"Loaded {len(images)} images from {folder_path}")
    return images, image_names
folder_path = "paintings/"
images, file_names = load_images(folder_path)
# Out:
# Loaded 2741 images from paintings/

# %%
#generate cracks with the voronoi function (takes a bit)
cracks = []
for i in range(len(images)):
    h,w = images[i].shape[:2]
    num_points = 300
    line_thickness = 1    
    curve_intensity = 1
    output_path = 'inverted_crack_mask/' + file_names[i]
    crack = generate_voronoi_cracks(w, h, num_points, line_thickness, curve_intensity, output_path)
    cracks.append(crack)
    print(i,w,h)
# Out:
# Crack pattern saved to inverted_crack_mask/427.jpg
# 0 512 512
# Crack pattern saved to inverted_crack_mask/1702.jpg
# 1 512 512
# Crack pattern saved to inverted_crack_mask/1906.jpg
# 2 512 512
# Crack pattern saved to inverted_crack_mask/2237.jpg
# 3 512 512
# Crack pattern saved to inverted_crack_mask/2518.jpg
# 4 512 512
# Crack pattern saved to inverted_crack_mask/2394.jpg
# 5 512 512
# Crack pattern saved to inverted_crack_mask/114.jpg
# 6 512 512
# Crack pattern saved to inverted_crack_mask/1421.jpg
# 7 512 512
# Crack pattern saved to inverted_crack_mask/965.jpg
# 8 512 512
# Crack pattern saved to inverted_crack_mask/13.jpg
# 9 512 512
# Crack pattern saved to inverted_crack_mask/371.jpg
# 10 512 512
# Crack pattern saved to inverted_crack_mask/1543.jpg
# 11 512 512
# Crack pattern saved to inverted_crack_mask/912.jpg
# 12 512 512
# Crack pattern saved to inverted_crack_mask/611.jpg
# 13 512 512
# Crack pattern saved to inverted_crack_mask/808.jpg
# 14 512 512
# Crack pattern saved to inverted_crack_mask/20.jpg
# 15 512 512
# Crack pattern saved to inverted_crack_mask/2034.jpg
# 16 512 512
# Crack pattern saved to inverted_crack_mask/270.jpg
# 17 512 512
# Crack pattern saved to inverted_crack_mask/952.jpg
# 18 512 512
# Crack pattern saved to inverted_crack_mask/2180.jpg
# 19 512 512
# Crack pattern saved to inverted_crack_mask/200.jpg
# 20 512 512
# Crack pattern saved to inverted_crack_mask/786.jpg
# 21 512 512
# Crack pattern saved to inverted_crack_mask/2598.jpg
# 22 512 512
# Crack pattern saved to inverted_crack_mask/1309.jpg
# 23 512 512
# Crack pattern saved to inverted_crack_mask/1631.jpg
# 24 512 512
# Crack pattern saved to inverted_crack_mask/152.jpg
# 25 512 512
# Crack pattern saved to inverted_crack_mask/1572.jpg
# 26 512 512
# Crack pattern saved to inverted_crack_mask/591.jpg
# 27 512 512
# Crack pattern saved to inverted_crack_mask/641.jpg
# 28 512 512
# Crack pattern saved to inverted_crack_mask/815.jpg
# 29 512 512
# Crack pattern saved to inverted_crack_mask/2276.jpg
# 30 512 512
# Crack pattern saved to inverted_crack_mask/635.jpg
# 31 512 512
# Crack pattern saved to inverted_crack_mask/2490.jpg
# 32 512 512
# Crack pattern saved to inverted_crack_mask/2036.jpg
# 33 512 512
# Crack pattern saved to inverted_crack_mask/73.jpg
# 34 512 512
# Crack pattern saved to inverted_crack_mask/155.jpg
# 35 512 512
# Crack pattern saved to inverted_crack_mask/535.jpg
# 36 512 512
# Crack pattern saved to inverted_crack_mask/2599.jpg
# 37 512 512
# Crack pattern saved to inverted_crack_mask/10.jpg
# 38 512 512
# Crack pattern saved to inverted_crack_mask/1337.jpg
# 39 512 512
# Crack pattern saved to inverted_crack_mask/141.jpg
# 40 512 512
# Crack pattern saved to inverted_crack_mask/1412.jpg
# 41 512 512
# Crack pattern saved to inverted_crack_mask/1782.jpg
# 42 512 512
# Crack pattern saved to inverted_crack_mask/1373.jpg
# 43 512 512
# Crack pattern saved to inverted_crack_mask/2709.jpg
# 44 512 512
# Crack pattern saved to inverted_crack_mask/943.jpg
# 45 512 512
# Crack pattern saved to inverted_crack_mask/1291.jpg
# 46 512 512
# Crack pattern saved to inverted_crack_mask/1442.jpg
# 47 512 512
# Crack pattern saved to inverted_crack_mask/945.jpg
# 48 512 512
# Crack pattern saved to inverted_crack_mask/1854.jpg
# 49 512 512
# Crack pattern saved to inverted_crack_mask/2584.jpg
# 50 512 512
# Crack pattern saved to inverted_crack_mask/2701.jpg
# 51 512 512
# Crack pattern saved to inverted_crack_mask/299.jpg
# 52 512 512
# Crack pattern saved to inverted_crack_mask/2467.jpg
# 53 512 512
# Crack pattern saved to inverted_crack_mask/2704.jpg
# 54 512 512
# Crack pattern saved to inverted_crack_mask/582.jpg
# 55 512 512
# Crack pattern saved to inverted_crack_mask/315.jpg
# 56 512 512
# Crack pattern saved to inverted_crack_mask/1601.jpg
# 57 512 512
# Crack pattern saved to inverted_crack_mask/1043.jpg
# 58 512 512
# Crack pattern saved to inverted_crack_mask/1616.jpg
# 59 512 512
# Crack pattern saved to inverted_crack_mask/1181.jpg
# 60 512 512
# Crack pattern saved to inverted_crack_mask/2003.jpg
# 61 512 512
# Crack pattern saved to inverted_crack_mask/2652.jpg
# 62 512 512
# Crack pattern saved to inverted_crack_mask/2285.jpg
# 63 512 512
# Crack pattern saved to inverted_crack_mask/1280.jpg
# 64 512 512
# Crack pattern saved to inverted_crack_mask/1713.jpg
# 65 512 512
# Crack pattern saved to inverted_crack_mask/185.jpg
# 66 512 512
# Crack pattern saved to inverted_crack_mask/2706.jpg
# 67 512 512
# Crack pattern saved to inverted_crack_mask/1482.jpg
# 68 512 512
# Crack pattern saved to inverted_crack_mask/383.jpg
# 69 512 512
# Crack pattern saved to inverted_crack_mask/2510.jpg
# 70 512 512
# Crack pattern saved to inverted_crack_mask/2291.jpg
# 71 512 512
# Crack pattern saved to inverted_crack_mask/1338.jpg
# 72 512 512
# Crack pattern saved to inverted_crack_mask/240.jpg
# 73 512 512
# Crack pattern saved to inverted_crack_mask/1820.jpg
# 74 512 512
# Crack pattern saved to inverted_crack_mask/1717.jpg
# 75 512 512
# Crack pattern saved to inverted_crack_mask/2038.jpg
# 76 512 512
# Crack pattern saved to inverted_crack_mask/1138.jpg
# 77 512 512
# Crack pattern saved to inverted_crack_mask/2347.jpg
# 78 512 512
# Crack pattern saved to inverted_crack_mask/1058.jpg
# 79 512 512
# Crack pattern saved to inverted_crack_mask/501.jpg
# 80 512 512
# Crack pattern saved to inverted_crack_mask/1040.jpg
# 81 512 512
# Crack pattern saved to inverted_crack_mask/404.jpg
# 82 512 512
# Crack pattern saved to inverted_crack_mask/730.jpg
# 83 512 512
# Crack pattern saved to inverted_crack_mask/652.jpg
# 84 512 512
# Crack pattern saved to inverted_crack_mask/344.jpg
# 85 512 512
# Crack pattern saved to inverted_crack_mask/2374.jpg
# 86 512 512
# Crack pattern saved to inverted_crack_mask/1257.jpg
# 87 512 512
# Crack pattern saved to inverted_crack_mask/913.jpg
# 88 512 512
# Crack pattern saved to inverted_crack_mask/2657.jpg
# 89 512 512
# Crack pattern saved to inverted_crack_mask/295.jpg
# 90 512 512
# Crack pattern saved to inverted_crack_mask/855.jpg
# 91 512 512
# Crack pattern saved to inverted_crack_mask/2492.jpg
# 92 512 512
# Crack pattern saved to inverted_crack_mask/1979.jpg
# 93 512 512
# Crack pattern saved to inverted_crack_mask/737.jpg
# 94 512 512
# Crack pattern saved to inverted_crack_mask/2708.jpg
# 95 512 512
# Crack pattern saved to inverted_crack_mask/1984.jpg
# 96 512 512
# Crack pattern saved to inverted_crack_mask/1268.jpg
# 97 512 512
# Crack pattern saved to inverted_crack_mask/1555.jpg
# 98 512 512
# Crack pattern saved to inverted_crack_mask/1453.jpg
# 99 512 512
# Crack pattern saved to inverted_crack_mask/1952.jpg
# 100 512 512
# Crack pattern saved to inverted_crack_mask/2117.jpg
# 101 512 512
# Crack pattern saved to inverted_crack_mask/585.jpg
# 102 512 512
# Crack pattern saved to inverted_crack_mask/1247.jpg
# 103 512 512
# Crack pattern saved to inverted_crack_mask/91.jpg
# 104 512 512
# Crack pattern saved to inverted_crack_mask/2672.jpg
# 105 512 512
# Crack pattern saved to inverted_crack_mask/1699.jpg
# 106 512 512
# Crack pattern saved to inverted_crack_mask/928.jpg
# 107 512 512
# Crack pattern saved to inverted_crack_mask/1238.jpg
# 108 512 512
# Crack pattern saved to inverted_crack_mask/38.jpg
# 109 512 512
# Crack pattern saved to inverted_crack_mask/289.jpg
# 110 512 512
# Crack pattern saved to inverted_crack_mask/263.jpg
# 111 512 512
# Crack pattern saved to inverted_crack_mask/739.jpg
# 112 512 512
# Crack pattern saved to inverted_crack_mask/1562.jpg
# 113 512 512
# Crack pattern saved to inverted_crack_mask/2364.jpg
# 114 512 512
# Crack pattern saved to inverted_crack_mask/402.jpg
# 115 512 512
# Crack pattern saved to inverted_crack_mask/1163.jpg
# 116 512 512
# Crack pattern saved to inverted_crack_mask/2572.jpg
# 117 512 512
# Crack pattern saved to inverted_crack_mask/508.jpg
# 118 512 512
# Crack pattern saved to inverted_crack_mask/2619.jpg
# 119 512 512
# Crack pattern saved to inverted_crack_mask/415.jpg
# 120 512 512
# Crack pattern saved to inverted_crack_mask/48.jpg
# 121 512 512
# Crack pattern saved to inverted_crack_mask/2095.jpg
# 122 512 512
# Crack pattern saved to inverted_crack_mask/1150.jpg
# 123 512 512
# Crack pattern saved to inverted_crack_mask/1232.jpg
# 124 512 512
# Crack pattern saved to inverted_crack_mask/557.jpg
# 125 512 512
# Crack pattern saved to inverted_crack_mask/2123.jpg
# 126 512 512
# Crack pattern saved to inverted_crack_mask/1152.jpg
# 127 512 512
# Crack pattern saved to inverted_crack_mask/760.jpg
# 128 512 512
# Crack pattern saved to inverted_crack_mask/1273.jpg
# 129 512 512
# Crack pattern saved to inverted_crack_mask/944.jpg
# 130 512 512
# Crack pattern saved to inverted_crack_mask/2145.jpg
# 131 512 512
# Crack pattern saved to inverted_crack_mask/24.jpg
# 132 512 512
# Crack pattern saved to inverted_crack_mask/1433.jpg
# 133 512 512
# Crack pattern saved to inverted_crack_mask/1281.jpg
# 134 512 512
# Crack pattern saved to inverted_crack_mask/2698.jpg
# 135 512 512
# Crack pattern saved to inverted_crack_mask/442.jpg
# 136 512 512
# Crack pattern saved to inverted_crack_mask/135.jpg
# 137 512 512
# Crack pattern saved to inverted_crack_mask/2521.jpg
# 138 512 512
# Crack pattern saved to inverted_crack_mask/833.jpg
# 139 512 512
# Crack pattern saved to inverted_crack_mask/1393.jpg
# 140 512 512
# Crack pattern saved to inverted_crack_mask/2088.jpg
# 141 512 512
# Crack pattern saved to inverted_crack_mask/789.jpg
# 142 512 512
# Crack pattern saved to inverted_crack_mask/781.jpg
# 143 512 512
# Crack pattern saved to inverted_crack_mask/2631.jpg
# 144 512 512
# Crack pattern saved to inverted_crack_mask/1199.jpg
# 145 512 512
# Crack pattern saved to inverted_crack_mask/2219.jpg
# 146 512 512
# Crack pattern saved to inverted_crack_mask/1383.jpg
# 147 512 512
# Crack pattern saved to inverted_crack_mask/1573.jpg
# 148 512 512
# Crack pattern saved to inverted_crack_mask/286.jpg
# 149 512 512
# Crack pattern saved to inverted_crack_mask/1783.jpg
# 150 512 512
# Crack pattern saved to inverted_crack_mask/1198.jpg
# 151 512 512
# Crack pattern saved to inverted_crack_mask/533.jpg
# 152 512 512
# Crack pattern saved to inverted_crack_mask/423.jpg
# 153 512 512
# Crack pattern saved to inverted_crack_mask/2327.jpg
# 154 512 512
# Crack pattern saved to inverted_crack_mask/2433.jpg
# 155 512 512
# Crack pattern saved to inverted_crack_mask/100.jpg
# 156 512 512
# Crack pattern saved to inverted_crack_mask/2735.jpg
# 157 512 512
# Crack pattern saved to inverted_crack_mask/2641.jpg
# 158 512 512
# Crack pattern saved to inverted_crack_mask/353.jpg
# 159 512 512
# Crack pattern saved to inverted_crack_mask/1871.jpg
# 160 512 512
# Crack pattern saved to inverted_crack_mask/1784.jpg
# 161 512 512
# Crack pattern saved to inverted_crack_mask/2384.jpg
# 162 512 512
# Crack pattern saved to inverted_crack_mask/990.jpg
# 163 512 512
# Crack pattern saved to inverted_crack_mask/963.jpg
# 164 512 512
# Crack pattern saved to inverted_crack_mask/2528.jpg
# 165 512 512
# Crack pattern saved to inverted_crack_mask/2126.jpg
# 166 512 512
# Crack pattern saved to inverted_crack_mask/2612.jpg
# 167 512 512
# Crack pattern saved to inverted_crack_mask/2489.jpg
# 168 512 512
# Crack pattern saved to inverted_crack_mask/97.jpg
# 169 512 512
# Crack pattern saved to inverted_crack_mask/1986.jpg
# 170 512 512
# Crack pattern saved to inverted_crack_mask/1333.jpg
# 171 512 512
# Crack pattern saved to inverted_crack_mask/1496.jpg
# 172 512 512
# Crack pattern saved to inverted_crack_mask/1484.jpg
# 173 512 512
# Crack pattern saved to inverted_crack_mask/1581.jpg
# 174 512 512
# Crack pattern saved to inverted_crack_mask/1278.jpg
# 175 512 512
# Crack pattern saved to inverted_crack_mask/1639.jpg
# 176 512 512
# Crack pattern saved to inverted_crack_mask/1613.jpg
# 177 512 512
# Crack pattern saved to inverted_crack_mask/2651.jpg
# 178 512 512
# Crack pattern saved to inverted_crack_mask/1248.jpg
# 179 512 512
# Crack pattern saved to inverted_crack_mask/1591.jpg
# 180 512 512
# Crack pattern saved to inverted_crack_mask/911.jpg
# 181 512 512
# Crack pattern saved to inverted_crack_mask/1683.jpg
# 182 512 512
# Crack pattern saved to inverted_crack_mask/568.jpg
# 183 512 512
# Crack pattern saved to inverted_crack_mask/2381.jpg
# 184 512 512
# Crack pattern saved to inverted_crack_mask/2643.jpg
# 185 512 512
# Crack pattern saved to inverted_crack_mask/852.jpg
# 186 512 512
# Crack pattern saved to inverted_crack_mask/547.jpg
# 187 512 512
# Crack pattern saved to inverted_crack_mask/471.jpg
# 188 512 512
# Crack pattern saved to inverted_crack_mask/1600.jpg
# 189 512 512
# Crack pattern saved to inverted_crack_mask/2428.jpg
# 190 512 512
# Crack pattern saved to inverted_crack_mask/2050.jpg
# 191 512 512
# Crack pattern saved to inverted_crack_mask/2054.jpg
# 192 512 512
# Crack pattern saved to inverted_crack_mask/772.jpg
# 193 512 512
# Crack pattern saved to inverted_crack_mask/1606.jpg
# 194 512 512
# Crack pattern saved to inverted_crack_mask/2620.jpg
# 195 512 512
# Crack pattern saved to inverted_crack_mask/2028.jpg
# 196 512 512
# Crack pattern saved to inverted_crack_mask/1459.jpg
# 197 512 512
# Crack pattern saved to inverted_crack_mask/820.jpg
# 198 512 512
# Crack pattern saved to inverted_crack_mask/869.jpg
# 199 512 512
# Crack pattern saved to inverted_crack_mask/700.jpg
# 200 512 512
# Crack pattern saved to inverted_crack_mask/2031.jpg
# 201 512 512
# Crack pattern saved to inverted_crack_mask/794.jpg
# 202 512 512
# Crack pattern saved to inverted_crack_mask/821.jpg
# 203 512 512
# Crack pattern saved to inverted_crack_mask/1599.jpg
# 204 512 512
# Crack pattern saved to inverted_crack_mask/1958.jpg
# 205 512 512
# Crack pattern saved to inverted_crack_mask/385.jpg
# 206 512 512
# Crack pattern saved to inverted_crack_mask/1904.jpg
# 207 512 512
# Crack pattern saved to inverted_crack_mask/727.jpg
# 208 512 512
# Crack pattern saved to inverted_crack_mask/2372.jpg
# 209 512 512
# Crack pattern saved to inverted_crack_mask/2560.jpg
# 210 512 512
# Crack pattern saved to inverted_crack_mask/2569.jpg
# 211 512 512
# Crack pattern saved to inverted_crack_mask/581.jpg
# 212 512 512
# Crack pattern saved to inverted_crack_mask/1912.jpg
# 213 512 512
# Crack pattern saved to inverted_crack_mask/2108.jpg
# 214 512 512
# Crack pattern saved to inverted_crack_mask/316.jpg
# 215 512 512
# Crack pattern saved to inverted_crack_mask/1276.jpg
# 216 512 512
# Crack pattern saved to inverted_crack_mask/1440.jpg
# 217 512 512
# Crack pattern saved to inverted_crack_mask/744.jpg
# 218 512 512
# Crack pattern saved to inverted_crack_mask/2368.jpg
# 219 512 512
# Crack pattern saved to inverted_crack_mask/458.jpg
# 220 512 512
# Crack pattern saved to inverted_crack_mask/847.jpg
# 221 512 512
# Crack pattern saved to inverted_crack_mask/2170.jpg
# 222 512 512
# Crack pattern saved to inverted_crack_mask/1667.jpg
# 223 512 512
# Crack pattern saved to inverted_crack_mask/867.jpg
# 224 512 512
# Crack pattern saved to inverted_crack_mask/1929.jpg
# 225 512 512
# Crack pattern saved to inverted_crack_mask/2012.jpg
# 226 512 512
# Crack pattern saved to inverted_crack_mask/5.jpg
# 227 512 512
# Crack pattern saved to inverted_crack_mask/1954.jpg
# 228 512 512
# Crack pattern saved to inverted_crack_mask/1618.jpg
# 229 512 512
# Crack pattern saved to inverted_crack_mask/1157.jpg
# 230 512 512
# Crack pattern saved to inverted_crack_mask/52.jpg
# 231 512 512
# Crack pattern saved to inverted_crack_mask/15.jpg
# 232 512 512
# Crack pattern saved to inverted_crack_mask/982.jpg
# 233 512 512
# Crack pattern saved to inverted_crack_mask/1159.jpg
# 234 512 512
# Crack pattern saved to inverted_crack_mask/382.jpg
# 235 512 512
# Crack pattern saved to inverted_crack_mask/430.jpg
# 236 512 512
# Crack pattern saved to inverted_crack_mask/2424.jpg
# 237 512 512
# Crack pattern saved to inverted_crack_mask/498.jpg
# 238 512 512
# Crack pattern saved to inverted_crack_mask/2440.jpg
# 239 512 512
# Crack pattern saved to inverted_crack_mask/1671.jpg
# 240 512 512
# Crack pattern saved to inverted_crack_mask/1473.jpg
# 241 512 512
# Crack pattern saved to inverted_crack_mask/1049.jpg
# 242 512 512
# Crack pattern saved to inverted_crack_mask/2096.jpg
# 243 512 512
# Crack pattern saved to inverted_crack_mask/418.jpg
# 244 512 512
# Crack pattern saved to inverted_crack_mask/2167.jpg
# 245 512 512
# Crack pattern saved to inverted_crack_mask/2443.jpg
# 246 512 512
# Crack pattern saved to inverted_crack_mask/2544.jpg
# 247 512 512
# Crack pattern saved to inverted_crack_mask/1050.jpg
# 248 512 512
# Crack pattern saved to inverted_crack_mask/1865.jpg
# 249 512 512
# Crack pattern saved to inverted_crack_mask/1322.jpg
# 250 512 512
# Crack pattern saved to inverted_crack_mask/2559.jpg
# 251 512 512
# Crack pattern saved to inverted_crack_mask/1842.jpg
# 252 512 512
# Crack pattern saved to inverted_crack_mask/1173.jpg
# 253 512 512
# Crack pattern saved to inverted_crack_mask/975.jpg
# 254 512 512
# Crack pattern saved to inverted_crack_mask/1685.jpg
# 255 512 512
# Crack pattern saved to inverted_crack_mask/2303.jpg
# 256 512 512
# Crack pattern saved to inverted_crack_mask/296.jpg
# 257 512 512
# Crack pattern saved to inverted_crack_mask/2588.jpg
# 258 512 512
# Crack pattern saved to inverted_crack_mask/2286.jpg
# 259 512 512
# Crack pattern saved to inverted_crack_mask/1553.jpg
# 260 512 512
# Crack pattern saved to inverted_crack_mask/1752.jpg
# 261 512 512
# Crack pattern saved to inverted_crack_mask/2299.jpg
# 262 512 512
# Crack pattern saved to inverted_crack_mask/656.jpg
# 263 512 512
# Crack pattern saved to inverted_crack_mask/1715.jpg
# 264 512 512
# Crack pattern saved to inverted_crack_mask/872.jpg
# 265 512 512
# Crack pattern saved to inverted_crack_mask/1190.jpg
# 266 512 512
# Crack pattern saved to inverted_crack_mask/710.jpg
# 267 512 512
# Crack pattern saved to inverted_crack_mask/663.jpg
# 268 512 512
# Crack pattern saved to inverted_crack_mask/1930.jpg
# 269 512 512
# Crack pattern saved to inverted_crack_mask/1435.jpg
# 270 512 512
# Crack pattern saved to inverted_crack_mask/2553.jpg
# 271 512 512
# Crack pattern saved to inverted_crack_mask/57.jpg
# 272 512 512
# Crack pattern saved to inverted_crack_mask/587.jpg
# 273 512 512
# Crack pattern saved to inverted_crack_mask/2729.jpg
# 274 512 512
# Crack pattern saved to inverted_crack_mask/2340.jpg
# 275 512 512
# Crack pattern saved to inverted_crack_mask/1085.jpg
# 276 512 512
# Crack pattern saved to inverted_crack_mask/629.jpg
# 277 512 512
# Crack pattern saved to inverted_crack_mask/1071.jpg
# 278 512 512
# Crack pattern saved to inverted_crack_mask/1568.jpg
# 279 512 512
# Crack pattern saved to inverted_crack_mask/71.jpg
# 280 512 512
# Crack pattern saved to inverted_crack_mask/1670.jpg
# 281 512 512
# Crack pattern saved to inverted_crack_mask/223.jpg
# 282 512 512
# Crack pattern saved to inverted_crack_mask/2005.jpg
# 283 512 512
# Crack pattern saved to inverted_crack_mask/1669.jpg
# 284 512 512
# Crack pattern saved to inverted_crack_mask/357.jpg
# 285 512 512
# Crack pattern saved to inverted_crack_mask/2025.jpg
# 286 512 512
# Crack pattern saved to inverted_crack_mask/1943.jpg
# 287 512 512
# Crack pattern saved to inverted_crack_mask/2058.jpg
# 288 512 512
# Crack pattern saved to inverted_crack_mask/1399.jpg
# 289 512 512
# Crack pattern saved to inverted_crack_mask/1810.jpg
# 290 512 512
# Crack pattern saved to inverted_crack_mask/2516.jpg
# 291 512 512
# Crack pattern saved to inverted_crack_mask/1938.jpg
# 292 512 512
# Crack pattern saved to inverted_crack_mask/1881.jpg
# 293 512 512
# Crack pattern saved to inverted_crack_mask/1239.jpg
# 294 512 512
# Crack pattern saved to inverted_crack_mask/350.jpg
# 295 512 512
# Crack pattern saved to inverted_crack_mask/2004.jpg
# 296 512 512
# Crack pattern saved to inverted_crack_mask/2067.jpg
# 297 512 512
# Crack pattern saved to inverted_crack_mask/1994.jpg
# 298 512 512
# Crack pattern saved to inverted_crack_mask/2558.jpg
# 299 512 512
# Crack pattern saved to inverted_crack_mask/1354.jpg
# 300 512 512
# Crack pattern saved to inverted_crack_mask/2314.jpg
# 301 512 512
# Crack pattern saved to inverted_crack_mask/365.jpg
# 302 512 512
# Crack pattern saved to inverted_crack_mask/1115.jpg
# 303 512 512
# Crack pattern saved to inverted_crack_mask/1024.jpg
# 304 512 512
# Crack pattern saved to inverted_crack_mask/1060.jpg
# 305 512 512
# Crack pattern saved to inverted_crack_mask/720.jpg
# 306 512 512
# Crack pattern saved to inverted_crack_mask/1301.jpg
# 307 512 512
# Crack pattern saved to inverted_crack_mask/1404.jpg
# 308 512 512
# Crack pattern saved to inverted_crack_mask/1469.jpg
# 309 512 512
# Crack pattern saved to inverted_crack_mask/1934.jpg
# 310 512 512
# Crack pattern saved to inverted_crack_mask/488.jpg
# 311 512 512
# Crack pattern saved to inverted_crack_mask/901.jpg
# 312 512 512
# Crack pattern saved to inverted_crack_mask/1586.jpg
# 313 512 512
# Crack pattern saved to inverted_crack_mask/2083.jpg
# 314 512 512
# Crack pattern saved to inverted_crack_mask/861.jpg
# 315 512 512
# Crack pattern saved to inverted_crack_mask/336.jpg
# 316 512 512
# Crack pattern saved to inverted_crack_mask/194.jpg
# 317 512 512
# Crack pattern saved to inverted_crack_mask/1054.jpg
# 318 512 512
# Crack pattern saved to inverted_crack_mask/1630.jpg
# 319 512 512
# Crack pattern saved to inverted_crack_mask/1736.jpg
# 320 512 512
# Crack pattern saved to inverted_crack_mask/131.jpg
# 321 512 512
# Crack pattern saved to inverted_crack_mask/235.jpg
# 322 512 512
# Crack pattern saved to inverted_crack_mask/2385.jpg
# 323 512 512
# Crack pattern saved to inverted_crack_mask/2614.jpg
# 324 512 512
# Crack pattern saved to inverted_crack_mask/1698.jpg
# 325 512 512
# Crack pattern saved to inverted_crack_mask/2411.jpg
# 326 512 512
# Crack pattern saved to inverted_crack_mask/1520.jpg
# 327 512 512
# Crack pattern saved to inverted_crack_mask/1557.jpg
# 328 512 512
# Crack pattern saved to inverted_crack_mask/2425.jpg
# 329 512 512
# Crack pattern saved to inverted_crack_mask/1464.jpg
# 330 512 512
# Crack pattern saved to inverted_crack_mask/1524.jpg
# 331 512 512
# Crack pattern saved to inverted_crack_mask/545.jpg
# 332 512 512
# Crack pattern saved to inverted_crack_mask/2164.jpg
# 333 512 512
# Crack pattern saved to inverted_crack_mask/989.jpg
# 334 512 512
# Crack pattern saved to inverted_crack_mask/1913.jpg
# 335 512 512
# Crack pattern saved to inverted_crack_mask/2220.jpg
# 336 512 512
# Crack pattern saved to inverted_crack_mask/2703.jpg
# 337 512 512
# Crack pattern saved to inverted_crack_mask/2282.jpg
# 338 512 512
# Crack pattern saved to inverted_crack_mask/1923.jpg
# 339 512 512
# Crack pattern saved to inverted_crack_mask/1314.jpg
# 340 512 512
# Crack pattern saved to inverted_crack_mask/2191.jpg
# 341 512 512
# Crack pattern saved to inverted_crack_mask/1327.jpg
# 342 512 512
# Crack pattern saved to inverted_crack_mask/2570.jpg
# 343 512 512
# Crack pattern saved to inverted_crack_mask/1255.jpg
# 344 512 512
# Crack pattern saved to inverted_crack_mask/2723.jpg
# 345 512 512
# Crack pattern saved to inverted_crack_mask/1571.jpg
# 346 512 512
# Crack pattern saved to inverted_crack_mask/731.jpg
# 347 512 512
# Crack pattern saved to inverted_crack_mask/504.jpg
# 348 512 512
# Crack pattern saved to inverted_crack_mask/1279.jpg
# 349 512 512
# Crack pattern saved to inverted_crack_mask/2377.jpg
# 350 512 512
# Crack pattern saved to inverted_crack_mask/1664.jpg
# 351 512 512
# Crack pattern saved to inverted_crack_mask/846.jpg
# 352 512 512
# Crack pattern saved to inverted_crack_mask/757.jpg
# 353 512 512
# Crack pattern saved to inverted_crack_mask/2476.jpg
# 354 512 512
# Crack pattern saved to inverted_crack_mask/226.jpg
# 355 512 512
# Crack pattern saved to inverted_crack_mask/2663.jpg
# 356 512 512
# Crack pattern saved to inverted_crack_mask/2738.jpg
# 357 512 512
# Crack pattern saved to inverted_crack_mask/2143.jpg
# 358 512 512
# Crack pattern saved to inverted_crack_mask/1454.jpg
# 359 512 512
# Crack pattern saved to inverted_crack_mask/1870.jpg
# 360 512 512
# Crack pattern saved to inverted_crack_mask/1976.jpg
# 361 512 512
# Crack pattern saved to inverted_crack_mask/2405.jpg
# 362 512 512
# Crack pattern saved to inverted_crack_mask/1408.jpg
# 363 512 512
# Crack pattern saved to inverted_crack_mask/1932.jpg
# 364 512 512
# Crack pattern saved to inverted_crack_mask/1256.jpg
# 365 512 512
# Crack pattern saved to inverted_crack_mask/2391.jpg
# 366 512 512
# Crack pattern saved to inverted_crack_mask/477.jpg
# 367 512 512
# Crack pattern saved to inverted_crack_mask/1944.jpg
# 368 512 512
# Crack pattern saved to inverted_crack_mask/2363.jpg
# 369 512 512
# Crack pattern saved to inverted_crack_mask/1537.jpg
# 370 512 512
# Crack pattern saved to inverted_crack_mask/1017.jpg
# 371 512 512
# Crack pattern saved to inverted_crack_mask/1035.jpg
# 372 512 512
# Crack pattern saved to inverted_crack_mask/2566.jpg
# 373 512 512
# Crack pattern saved to inverted_crack_mask/777.jpg
# 374 512 512
# Crack pattern saved to inverted_crack_mask/1439.jpg
# 375 512 512
# Crack pattern saved to inverted_crack_mask/2437.jpg
# 376 512 512
# Crack pattern saved to inverted_crack_mask/510.jpg
# 377 512 512
# Crack pattern saved to inverted_crack_mask/2029.jpg
# 378 512 512
# Crack pattern saved to inverted_crack_mask/281.jpg
# 379 512 512
# Crack pattern saved to inverted_crack_mask/1662.jpg
# 380 512 512
# Crack pattern saved to inverted_crack_mask/2539.jpg
# 381 512 512
# Crack pattern saved to inverted_crack_mask/159.jpg
# 382 512 512
# Crack pattern saved to inverted_crack_mask/1013.jpg
# 383 512 512
# Crack pattern saved to inverted_crack_mask/1443.jpg
# 384 512 512
# Crack pattern saved to inverted_crack_mask/2468.jpg
# 385 512 512
# Crack pattern saved to inverted_crack_mask/1819.jpg
# 386 512 512
# Crack pattern saved to inverted_crack_mask/2630.jpg
# 387 512 512
# Crack pattern saved to inverted_crack_mask/2124.jpg
# 388 512 512
# Crack pattern saved to inverted_crack_mask/2356.jpg
# 389 512 512
# Crack pattern saved to inverted_crack_mask/83.jpg
# 390 512 512
# Crack pattern saved to inverted_crack_mask/2475.jpg
# 391 512 512
# Crack pattern saved to inverted_crack_mask/831.jpg
# 392 512 512
# Crack pattern saved to inverted_crack_mask/369.jpg
# 393 512 512
# Crack pattern saved to inverted_crack_mask/1475.jpg
# 394 512 512
# Crack pattern saved to inverted_crack_mask/1034.jpg
# 395 512 512
# Crack pattern saved to inverted_crack_mask/2092.jpg
# 396 512 512
# Crack pattern saved to inverted_crack_mask/665.jpg
# 397 512 512
# Crack pattern saved to inverted_crack_mask/2397.jpg
# 398 512 512
# Crack pattern saved to inverted_crack_mask/812.jpg
# 399 512 512
# Crack pattern saved to inverted_crack_mask/25.jpg
# 400 512 512
# Crack pattern saved to inverted_crack_mask/147.jpg
# 401 512 512
# Crack pattern saved to inverted_crack_mask/233.jpg
# 402 512 512
# Crack pattern saved to inverted_crack_mask/805.jpg
# 403 512 512
# Crack pattern saved to inverted_crack_mask/446.jpg
# 404 512 512
# Crack pattern saved to inverted_crack_mask/333.jpg
# 405 512 512
# Crack pattern saved to inverted_crack_mask/62.jpg
# 406 512 512
# Crack pattern saved to inverted_crack_mask/1914.jpg
# 407 512 512
# Crack pattern saved to inverted_crack_mask/2102.jpg
# 408 512 512
# Crack pattern saved to inverted_crack_mask/0.jpg
# 409 512 512
# Crack pattern saved to inverted_crack_mask/1211.jpg
# 410 512 512
# Crack pattern saved to inverted_crack_mask/339.jpg
# 411 512 512
# Crack pattern saved to inverted_crack_mask/1175.jpg
# 412 512 512
# Crack pattern saved to inverted_crack_mask/1155.jpg
# 413 512 512
# Crack pattern saved to inverted_crack_mask/875.jpg
# 414 512 512
# Crack pattern saved to inverted_crack_mask/2264.jpg
# 415 512 512
# Crack pattern saved to inverted_crack_mask/199.jpg
# 416 512 512
# Crack pattern saved to inverted_crack_mask/2198.jpg
# 417 512 512
# Crack pattern saved to inverted_crack_mask/536.jpg
# 418 512 512
# Crack pattern saved to inverted_crack_mask/679.jpg
# 419 512 512
# Crack pattern saved to inverted_crack_mask/774.jpg
# 420 512 512
# Crack pattern saved to inverted_crack_mask/23.jpg
# 421 512 512
# Crack pattern saved to inverted_crack_mask/1304.jpg
# 422 512 512
# Crack pattern saved to inverted_crack_mask/2189.jpg
# 423 512 512
# Crack pattern saved to inverted_crack_mask/1939.jpg
# 424 512 512
# Crack pattern saved to inverted_crack_mask/1895.jpg
# 425 512 512
# Crack pattern saved to inverted_crack_mask/1251.jpg
# 426 512 512
# Crack pattern saved to inverted_crack_mask/2503.jpg
# 427 512 512
# Crack pattern saved to inverted_crack_mask/1813.jpg
# 428 512 512
# Crack pattern saved to inverted_crack_mask/2591.jpg
# 429 512 512
# Crack pattern saved to inverted_crack_mask/2716.jpg
# 430 512 512
# Crack pattern saved to inverted_crack_mask/41.jpg
# 431 512 512
# Crack pattern saved to inverted_crack_mask/995.jpg
# 432 512 512
# Crack pattern saved to inverted_crack_mask/655.jpg
# 433 512 512
# Crack pattern saved to inverted_crack_mask/2506.jpg
# 434 512 512
# Crack pattern saved to inverted_crack_mask/575.jpg
# 435 512 512
# Crack pattern saved to inverted_crack_mask/2592.jpg
# 436 512 512
# Crack pattern saved to inverted_crack_mask/2312.jpg
# 437 512 512
# Crack pattern saved to inverted_crack_mask/2346.jpg
# 438 512 512
# Crack pattern saved to inverted_crack_mask/2413.jpg
# 439 512 512
# Crack pattern saved to inverted_crack_mask/878.jpg
# 440 512 512
# Crack pattern saved to inverted_crack_mask/414.jpg
# 441 512 512
# Crack pattern saved to inverted_crack_mask/556.jpg
# 442 512 512
# Crack pattern saved to inverted_crack_mask/2073.jpg
# 443 512 512
# Crack pattern saved to inverted_crack_mask/1413.jpg
# 444 512 512
# Crack pattern saved to inverted_crack_mask/2183.jpg
# 445 512 512
# Crack pattern saved to inverted_crack_mask/1210.jpg
# 446 512 512
# Crack pattern saved to inverted_crack_mask/256.jpg
# 447 512 512
# Crack pattern saved to inverted_crack_mask/2213.jpg
# 448 512 512
# Crack pattern saved to inverted_crack_mask/987.jpg
# 449 512 512
# Crack pattern saved to inverted_crack_mask/459.jpg
# 450 512 512
# Crack pattern saved to inverted_crack_mask/2087.jpg
# 451 512 512
# Crack pattern saved to inverted_crack_mask/138.jpg
# 452 512 512
# Crack pattern saved to inverted_crack_mask/1649.jpg
# 453 512 512
# Crack pattern saved to inverted_crack_mask/343.jpg
# 454 512 512
# Crack pattern saved to inverted_crack_mask/219.jpg
# 455 512 512
# Crack pattern saved to inverted_crack_mask/2499.jpg
# 456 512 512
# Crack pattern saved to inverted_crack_mask/1093.jpg
# 457 512 512
# Crack pattern saved to inverted_crack_mask/1044.jpg
# 458 512 512
# Crack pattern saved to inverted_crack_mask/1425.jpg
# 459 512 512
# Crack pattern saved to inverted_crack_mask/433.jpg
# 460 512 512
# Crack pattern saved to inverted_crack_mask/103.jpg
# 461 512 512
# Crack pattern saved to inverted_crack_mask/2420.jpg
# 462 512 512
# Crack pattern saved to inverted_crack_mask/1590.jpg
# 463 512 512
# Crack pattern saved to inverted_crack_mask/625.jpg
# 464 512 512
# Crack pattern saved to inverted_crack_mask/1004.jpg
# 465 512 512
# Crack pattern saved to inverted_crack_mask/2589.jpg
# 466 512 512
# Crack pattern saved to inverted_crack_mask/463.jpg
# 467 512 512
# Crack pattern saved to inverted_crack_mask/2407.jpg
# 468 512 512
# Crack pattern saved to inverted_crack_mask/1447.jpg
# 469 512 512
# Crack pattern saved to inverted_crack_mask/2485.jpg
# 470 512 512
# Crack pattern saved to inverted_crack_mask/1716.jpg
# 471 512 512
# Crack pattern saved to inverted_crack_mask/1066.jpg
# 472 512 512
# Crack pattern saved to inverted_crack_mask/60.jpg
# 473 512 512
# Crack pattern saved to inverted_crack_mask/2505.jpg
# 474 512 512
# Crack pattern saved to inverted_crack_mask/2386.jpg
# 475 512 512
# Crack pattern saved to inverted_crack_mask/1240.jpg
# 476 512 512
# Crack pattern saved to inverted_crack_mask/2627.jpg
# 477 512 512
# Crack pattern saved to inverted_crack_mask/1498.jpg
# 478 512 512
# Crack pattern saved to inverted_crack_mask/923.jpg
# 479 512 512
# Crack pattern saved to inverted_crack_mask/1920.jpg
# 480 512 512
# Crack pattern saved to inverted_crack_mask/2085.jpg
# 481 512 512
# Crack pattern saved to inverted_crack_mask/1844.jpg
# 482 512 512
# Crack pattern saved to inverted_crack_mask/1859.jpg
# 483 512 512
# Crack pattern saved to inverted_crack_mask/1202.jpg
# 484 512 512
# Crack pattern saved to inverted_crack_mask/2162.jpg
# 485 512 512
# Crack pattern saved to inverted_crack_mask/2208.jpg
# 486 512 512
# Crack pattern saved to inverted_crack_mask/2179.jpg
# 487 512 512
# Crack pattern saved to inverted_crack_mask/1423.jpg
# 488 512 512
# Crack pattern saved to inverted_crack_mask/806.jpg
# 489 512 512
# Crack pattern saved to inverted_crack_mask/577.jpg
# 490 512 512
# Crack pattern saved to inverted_crack_mask/107.jpg
# 491 512 512
# Crack pattern saved to inverted_crack_mask/1580.jpg
# 492 512 512
# Crack pattern saved to inverted_crack_mask/2740.jpg
# 493 512 512
# Crack pattern saved to inverted_crack_mask/480.jpg
# 494 512 512
# Crack pattern saved to inverted_crack_mask/2111.jpg
# 495 512 512
# Crack pattern saved to inverted_crack_mask/1532.jpg
# 496 512 512
# Crack pattern saved to inverted_crack_mask/466.jpg
# 497 512 512
# Crack pattern saved to inverted_crack_mask/921.jpg
# 498 512 512
# Crack pattern saved to inverted_crack_mask/783.jpg
# 499 512 512
# Crack pattern saved to inverted_crack_mask/2568.jpg
# 500 512 512
# Crack pattern saved to inverted_crack_mask/276.jpg
# 501 512 512
# Crack pattern saved to inverted_crack_mask/2720.jpg
# 502 512 512
# Crack pattern saved to inverted_crack_mask/1061.jpg
# 503 512 512
# Crack pattern saved to inverted_crack_mask/2043.jpg
# 504 512 512
# Crack pattern saved to inverted_crack_mask/845.jpg
# 505 512 512
# Crack pattern saved to inverted_crack_mask/193.jpg
# 506 512 512
# Crack pattern saved to inverted_crack_mask/1326.jpg
# 507 512 512
# Crack pattern saved to inverted_crack_mask/79.jpg
# 508 512 512
# Crack pattern saved to inverted_crack_mask/368.jpg
# 509 512 512
# Crack pattern saved to inverted_crack_mask/2001.jpg
# 510 512 512
# Crack pattern saved to inverted_crack_mask/1164.jpg
# 511 512 512
# Crack pattern saved to inverted_crack_mask/2640.jpg
# 512 512 512
# Crack pattern saved to inverted_crack_mask/2480.jpg
# 513 512 512
# Crack pattern saved to inverted_crack_mask/1733.jpg
# 514 512 512
# Crack pattern saved to inverted_crack_mask/2638.jpg
# 515 512 512
# Crack pattern saved to inverted_crack_mask/953.jpg
# 516 512 512
# Crack pattern saved to inverted_crack_mask/2150.jpg
# 517 512 512
# Crack pattern saved to inverted_crack_mask/1946.jpg
# 518 512 512
# Crack pattern saved to inverted_crack_mask/1651.jpg
# 519 512 512
# Crack pattern saved to inverted_crack_mask/2469.jpg
# 520 512 512
# Crack pattern saved to inverted_crack_mask/1324.jpg
# 521 512 512
# Crack pattern saved to inverted_crack_mask/1917.jpg
# 522 512 512
# Crack pattern saved to inverted_crack_mask/1217.jpg
# 523 512 512
# Crack pattern saved to inverted_crack_mask/1076.jpg
# 524 512 512
# Crack pattern saved to inverted_crack_mask/92.jpg
# 525 512 512
# Crack pattern saved to inverted_crack_mask/2120.jpg
# 526 512 512
# Crack pattern saved to inverted_crack_mask/122.jpg
# 527 512 512
# Crack pattern saved to inverted_crack_mask/2574.jpg
# 528 512 512
# Crack pattern saved to inverted_crack_mask/864.jpg
# 529 512 512
# Crack pattern saved to inverted_crack_mask/580.jpg
# 530 512 512
# Crack pattern saved to inverted_crack_mask/926.jpg
# 531 512 512
# Crack pattern saved to inverted_crack_mask/21.jpg
# 532 512 512
# Crack pattern saved to inverted_crack_mask/616.jpg
# 533 512 512
# Crack pattern saved to inverted_crack_mask/2132.jpg
# 534 512 512
# Crack pattern saved to inverted_crack_mask/1959.jpg
# 535 512 512
# Crack pattern saved to inverted_crack_mask/637.jpg
# 536 512 512
# Crack pattern saved to inverted_crack_mask/59.jpg
# 537 512 512
# Crack pattern saved to inverted_crack_mask/904.jpg
# 538 512 512
# Crack pattern saved to inverted_crack_mask/359.jpg
# 539 512 512
# Crack pattern saved to inverted_crack_mask/1344.jpg
# 540 512 512
# Crack pattern saved to inverted_crack_mask/2645.jpg
# 541 512 512
# Crack pattern saved to inverted_crack_mask/2296.jpg
# 542 512 512
# Crack pattern saved to inverted_crack_mask/942.jpg
# 543 512 512
# Crack pattern saved to inverted_crack_mask/2580.jpg
# 544 512 512
# Crack pattern saved to inverted_crack_mask/685.jpg
# 545 512 512
# Crack pattern saved to inverted_crack_mask/749.jpg
# 546 512 512
# Crack pattern saved to inverted_crack_mask/111.jpg
# 547 512 512
# Crack pattern saved to inverted_crack_mask/672.jpg
# 548 512 512
# Crack pattern saved to inverted_crack_mask/1862.jpg
# 549 512 512
# Crack pattern saved to inverted_crack_mask/49.jpg
# 550 512 512
# Crack pattern saved to inverted_crack_mask/1977.jpg
# 551 512 512
# Crack pattern saved to inverted_crack_mask/1975.jpg
# 552 512 512
# Crack pattern saved to inverted_crack_mask/883.jpg
# 553 512 512
# Crack pattern saved to inverted_crack_mask/35.jpg
# 554 512 512
# Crack pattern saved to inverted_crack_mask/1031.jpg
# 555 512 512
# Crack pattern saved to inverted_crack_mask/2236.jpg
# 556 512 512
# Crack pattern saved to inverted_crack_mask/2125.jpg
# 557 512 512
# Crack pattern saved to inverted_crack_mask/1364.jpg
# 558 512 512
# Crack pattern saved to inverted_crack_mask/2361.jpg
# 559 512 512
# Crack pattern saved to inverted_crack_mask/1332.jpg
# 560 512 512
# Crack pattern saved to inverted_crack_mask/183.jpg
# 561 512 512
# Crack pattern saved to inverted_crack_mask/1806.jpg
# 562 512 512
# Crack pattern saved to inverted_crack_mask/1575.jpg
# 563 512 512
# Crack pattern saved to inverted_crack_mask/1465.jpg
# 564 512 512
# Crack pattern saved to inverted_crack_mask/2129.jpg
# 565 512 512
# Crack pattern saved to inverted_crack_mask/2103.jpg
# 566 512 512
# Crack pattern saved to inverted_crack_mask/207.jpg
# 567 512 512
# Crack pattern saved to inverted_crack_mask/2719.jpg
# 568 512 512
# Crack pattern saved to inverted_crack_mask/1559.jpg
# 569 512 512
# Crack pattern saved to inverted_crack_mask/741.jpg
# 570 512 512
# Crack pattern saved to inverted_crack_mask/1072.jpg
# 571 512 512
# Crack pattern saved to inverted_crack_mask/2594.jpg
# 572 512 512
# Crack pattern saved to inverted_crack_mask/19.jpg
# 573 512 512
# Crack pattern saved to inverted_crack_mask/303.jpg
# 574 512 512
# Crack pattern saved to inverted_crack_mask/2310.jpg
# 575 512 512
# Crack pattern saved to inverted_crack_mask/1841.jpg
# 576 512 512
# Crack pattern saved to inverted_crack_mask/1674.jpg
# 577 512 512
# Crack pattern saved to inverted_crack_mask/1774.jpg
# 578 512 512
# Crack pattern saved to inverted_crack_mask/1094.jpg
# 579 512 512
# Crack pattern saved to inverted_crack_mask/2176.jpg
# 580 512 512
# Crack pattern saved to inverted_crack_mask/379.jpg
# 581 512 512
# Crack pattern saved to inverted_crack_mask/332.jpg
# 582 512 512
# Crack pattern saved to inverted_crack_mask/2685.jpg
# 583 512 512
# Crack pattern saved to inverted_crack_mask/1924.jpg
# 584 512 512
# Crack pattern saved to inverted_crack_mask/1608.jpg
# 585 512 512
# Crack pattern saved to inverted_crack_mask/2011.jpg
# 586 512 512
# Crack pattern saved to inverted_crack_mask/1142.jpg
# 587 512 512
# Crack pattern saved to inverted_crack_mask/27.jpg
# 588 512 512
# Crack pattern saved to inverted_crack_mask/1763.jpg
# 589 512 512
# Crack pattern saved to inverted_crack_mask/1707.jpg
# 590 512 512
# Crack pattern saved to inverted_crack_mask/1363.jpg
# 591 512 512
# Crack pattern saved to inverted_crack_mask/2244.jpg
# 592 512 512
# Crack pattern saved to inverted_crack_mask/761.jpg
# 593 512 512
# Crack pattern saved to inverted_crack_mask/305.jpg
# 594 512 512
# Crack pattern saved to inverted_crack_mask/69.jpg
# 595 512 512
# Crack pattern saved to inverted_crack_mask/966.jpg
# 596 512 512
# Crack pattern saved to inverted_crack_mask/2542.jpg
# 597 512 512
# Crack pattern saved to inverted_crack_mask/2644.jpg
# 598 512 512
# Crack pattern saved to inverted_crack_mask/920.jpg
# 599 512 512
# Crack pattern saved to inverted_crack_mask/197.jpg
# 600 512 512
# Crack pattern saved to inverted_crack_mask/1990.jpg
# 601 512 512
# Crack pattern saved to inverted_crack_mask/444.jpg
# 602 512 512
# Crack pattern saved to inverted_crack_mask/2549.jpg
# 603 512 512
# Crack pattern saved to inverted_crack_mask/1468.jpg
# 604 512 512
# Crack pattern saved to inverted_crack_mask/275.jpg
# 605 512 512
# Crack pattern saved to inverted_crack_mask/1516.jpg
# 606 512 512
# Crack pattern saved to inverted_crack_mask/1365.jpg
# 607 512 512
# Crack pattern saved to inverted_crack_mask/160.jpg
# 608 512 512
# Crack pattern saved to inverted_crack_mask/1675.jpg
# 609 512 512
# Crack pattern saved to inverted_crack_mask/2675.jpg
# 610 512 512
# Crack pattern saved to inverted_crack_mask/2530.jpg
# 611 512 512
# Crack pattern saved to inverted_crack_mask/1029.jpg
# 612 512 512
# Crack pattern saved to inverted_crack_mask/1849.jpg
# 613 512 512
# Crack pattern saved to inverted_crack_mask/653.jpg
# 614 512 512
# Crack pattern saved to inverted_crack_mask/615.jpg
# 615 512 512
# Crack pattern saved to inverted_crack_mask/1275.jpg
# 616 512 512
# Crack pattern saved to inverted_crack_mask/596.jpg
# 617 512 512
# Crack pattern saved to inverted_crack_mask/2197.jpg
# 618 512 512
# Crack pattern saved to inverted_crack_mask/187.jpg
# 619 512 512
# Crack pattern saved to inverted_crack_mask/931.jpg
# 620 512 512
# Crack pattern saved to inverted_crack_mask/420.jpg
# 621 512 512
# Crack pattern saved to inverted_crack_mask/564.jpg
# 622 512 512
# Crack pattern saved to inverted_crack_mask/1356.jpg
# 623 512 512
# Crack pattern saved to inverted_crack_mask/1282.jpg
# 624 512 512
# Crack pattern saved to inverted_crack_mask/1676.jpg
# 625 512 512
# Crack pattern saved to inverted_crack_mask/2388.jpg
# 626 512 512
# Crack pattern saved to inverted_crack_mask/1216.jpg
# 627 512 512
# Crack pattern saved to inverted_crack_mask/791.jpg
# 628 512 512
# Crack pattern saved to inverted_crack_mask/936.jpg
# 629 512 512
# Crack pattern saved to inverted_crack_mask/858.jpg
# 630 512 512
# Crack pattern saved to inverted_crack_mask/297.jpg
# 631 512 512
# Crack pattern saved to inverted_crack_mask/843.jpg
# 632 512 512
# Crack pattern saved to inverted_crack_mask/1297.jpg
# 633 512 512
# Crack pattern saved to inverted_crack_mask/1476.jpg
# 634 512 512
# Crack pattern saved to inverted_crack_mask/1892.jpg
# 635 512 512
# Crack pattern saved to inverted_crack_mask/2406.jpg
# 636 512 512
# Crack pattern saved to inverted_crack_mask/2104.jpg
# 637 512 512
# Crack pattern saved to inverted_crack_mask/894.jpg
# 638 512 512
# Crack pattern saved to inverted_crack_mask/2554.jpg
# 639 512 512
# Crack pattern saved to inverted_crack_mask/1271.jpg
# 640 512 512
# Crack pattern saved to inverted_crack_mask/1292.jpg
# 641 512 512
# Crack pattern saved to inverted_crack_mask/1376.jpg
# 642 512 512
# Crack pattern saved to inverted_crack_mask/1661.jpg
# 643 512 512
# Crack pattern saved to inverted_crack_mask/1728.jpg
# 644 512 512
# Crack pattern saved to inverted_crack_mask/1517.jpg
# 645 512 512
# Crack pattern saved to inverted_crack_mask/436.jpg
# 646 512 512
# Crack pattern saved to inverted_crack_mask/1843.jpg
# 647 512 512
# Crack pattern saved to inverted_crack_mask/2401.jpg
# 648 512 512
# Crack pattern saved to inverted_crack_mask/449.jpg
# 649 512 512
# Crack pattern saved to inverted_crack_mask/2414.jpg
# 650 512 512
# Crack pattern saved to inverted_crack_mask/17.jpg
# 651 512 512
# Crack pattern saved to inverted_crack_mask/1694.jpg
# 652 512 512
# Crack pattern saved to inverted_crack_mask/2422.jpg
# 653 512 512
# Crack pattern saved to inverted_crack_mask/1070.jpg
# 654 512 512
# Crack pattern saved to inverted_crack_mask/2022.jpg
# 655 512 512
# Crack pattern saved to inverted_crack_mask/424.jpg
# 656 512 512
# Crack pattern saved to inverted_crack_mask/2654.jpg
# 657 512 512
# Crack pattern saved to inverted_crack_mask/832.jpg
# 658 512 512
# Crack pattern saved to inverted_crack_mask/2537.jpg
# 659 512 512
# Crack pattern saved to inverted_crack_mask/1750.jpg
# 660 512 512
# Crack pattern saved to inverted_crack_mask/1187.jpg
# 661 512 512
# Crack pattern saved to inverted_crack_mask/1725.jpg
# 662 512 512
# Crack pattern saved to inverted_crack_mask/1512.jpg
# 663 512 512
# Crack pattern saved to inverted_crack_mask/524.jpg
# 664 512 512
# Crack pattern saved to inverted_crack_mask/1330.jpg
# 665 512 512
# Crack pattern saved to inverted_crack_mask/1307.jpg
# 666 512 512
# Crack pattern saved to inverted_crack_mask/1866.jpg
# 667 512 512
# Crack pattern saved to inverted_crack_mask/2174.jpg
# 668 512 512
# Crack pattern saved to inverted_crack_mask/1350.jpg
# 669 512 512
# Crack pattern saved to inverted_crack_mask/1754.jpg
# 670 512 512
# Crack pattern saved to inverted_crack_mask/503.jpg
# 671 512 512
# Crack pattern saved to inverted_crack_mask/386.jpg
# 672 512 512
# Crack pattern saved to inverted_crack_mask/1409.jpg
# 673 512 512
# Crack pattern saved to inverted_crack_mask/1804.jpg
# 674 512 512
# Crack pattern saved to inverted_crack_mask/729.jpg
# 675 512 512
# Crack pattern saved to inverted_crack_mask/2226.jpg
# 676 512 512
# Crack pattern saved to inverted_crack_mask/2250.jpg
# 677 512 512
# Crack pattern saved to inverted_crack_mask/2555.jpg
# 678 512 512
# Crack pattern saved to inverted_crack_mask/1010.jpg
# 679 512 512
# Crack pattern saved to inverted_crack_mask/1461.jpg
# 680 512 512
# Crack pattern saved to inverted_crack_mask/277.jpg
# 681 512 512
# Crack pattern saved to inverted_crack_mask/713.jpg
# 682 512 512
# Crack pattern saved to inverted_crack_mask/2338.jpg
# 683 512 512
# Crack pattern saved to inverted_crack_mask/2493.jpg
# 684 512 512
# Crack pattern saved to inverted_crack_mask/1542.jpg
# 685 512 512
# Crack pattern saved to inverted_crack_mask/2320.jpg
# 686 512 512
# Crack pattern saved to inverted_crack_mask/627.jpg
# 687 512 512
# Crack pattern saved to inverted_crack_mask/434.jpg
# 688 512 512
# Crack pattern saved to inverted_crack_mask/515.jpg
# 689 512 512
# Crack pattern saved to inverted_crack_mask/2168.jpg
# 690 512 512
# Crack pattern saved to inverted_crack_mask/376.jpg
# 691 512 512
# Crack pattern saved to inverted_crack_mask/1868.jpg
# 692 512 512
# Crack pattern saved to inverted_crack_mask/1250.jpg
# 693 512 512
# Crack pattern saved to inverted_crack_mask/823.jpg
# 694 512 512
# Crack pattern saved to inverted_crack_mask/1026.jpg
# 695 512 512
# Crack pattern saved to inverted_crack_mask/1241.jpg
# 696 512 512
# Crack pattern saved to inverted_crack_mask/2739.jpg
# 697 512 512
# Crack pattern saved to inverted_crack_mask/2041.jpg
# 698 512 512
# Crack pattern saved to inverted_crack_mask/898.jpg
# 699 512 512
# Crack pattern saved to inverted_crack_mask/218.jpg
# 700 512 512
# Crack pattern saved to inverted_crack_mask/1818.jpg
# 701 512 512
# Crack pattern saved to inverted_crack_mask/425.jpg
# 702 512 512
# Crack pattern saved to inverted_crack_mask/1220.jpg
# 703 512 512
# Crack pattern saved to inverted_crack_mask/1578.jpg
# 704 512 512
# Crack pattern saved to inverted_crack_mask/1259.jpg
# 705 512 512
# Crack pattern saved to inverted_crack_mask/1780.jpg
# 706 512 512
# Crack pattern saved to inverted_crack_mask/2032.jpg
# 707 512 512
# Crack pattern saved to inverted_crack_mask/983.jpg
# 708 512 512
# Crack pattern saved to inverted_crack_mask/1167.jpg
# 709 512 512
# Crack pattern saved to inverted_crack_mask/1540.jpg
# 710 512 512
# Crack pattern saved to inverted_crack_mask/2534.jpg
# 711 512 512
# Crack pattern saved to inverted_crack_mask/1545.jpg
# 712 512 512
# Crack pattern saved to inverted_crack_mask/1792.jpg
# 713 512 512
# Crack pattern saved to inverted_crack_mask/972.jpg
# 714 512 512
# Crack pattern saved to inverted_crack_mask/1487.jpg
# 715 512 512
# Crack pattern saved to inverted_crack_mask/1767.jpg
# 716 512 512
# Crack pattern saved to inverted_crack_mask/1436.jpg
# 717 512 512
# Crack pattern saved to inverted_crack_mask/90.jpg
# 718 512 512
# Crack pattern saved to inverted_crack_mask/1318.jpg
# 719 512 512
# Crack pattern saved to inverted_crack_mask/169.jpg
# 720 512 512
# Crack pattern saved to inverted_crack_mask/129.jpg
# 721 512 512
# Crack pattern saved to inverted_crack_mask/500.jpg
# 722 512 512
# Crack pattern saved to inverted_crack_mask/646.jpg
# 723 512 512
# Crack pattern saved to inverted_crack_mask/742.jpg
# 724 512 512
# Crack pattern saved to inverted_crack_mask/1378.jpg
# 725 512 512
# Crack pattern saved to inverted_crack_mask/215.jpg
# 726 512 512
# Crack pattern saved to inverted_crack_mask/2375.jpg
# 727 512 512
# Crack pattern saved to inverted_crack_mask/895.jpg
# 728 512 512
# Crack pattern saved to inverted_crack_mask/571.jpg
# 729 512 512
# Crack pattern saved to inverted_crack_mask/157.jpg
# 730 512 512
# Crack pattern saved to inverted_crack_mask/407.jpg
# 731 512 512
# Crack pattern saved to inverted_crack_mask/954.jpg
# 732 512 512
# Crack pattern saved to inverted_crack_mask/178.jpg
# 733 512 512
# Crack pattern saved to inverted_crack_mask/1926.jpg
# 734 512 512
# Crack pattern saved to inverted_crack_mask/1771.jpg
# 735 512 512
# Crack pattern saved to inverted_crack_mask/1411.jpg
# 736 512 512
# Crack pattern saved to inverted_crack_mask/1265.jpg
# 737 512 512
# Crack pattern saved to inverted_crack_mask/421.jpg
# 738 512 512
# Crack pattern saved to inverted_crack_mask/2081.jpg
# 739 512 512
# Crack pattern saved to inverted_crack_mask/412.jpg
# 740 512 512
# Crack pattern saved to inverted_crack_mask/2187.jpg
# 741 512 512
# Crack pattern saved to inverted_crack_mask/1846.jpg
# 742 512 512
# Crack pattern saved to inverted_crack_mask/2731.jpg
# 743 512 512
# Crack pattern saved to inverted_crack_mask/54.jpg
# 744 512 512
# Crack pattern saved to inverted_crack_mask/1420.jpg
# 745 512 512
# Crack pattern saved to inverted_crack_mask/1229.jpg
# 746 512 512
# Crack pattern saved to inverted_crack_mask/210.jpg
# 747 512 512
# Crack pattern saved to inverted_crack_mask/1389.jpg
# 748 512 512
# Crack pattern saved to inverted_crack_mask/2318.jpg
# 749 512 512
# Crack pattern saved to inverted_crack_mask/1355.jpg
# 750 512 512
# Crack pattern saved to inverted_crack_mask/224.jpg
# 751 512 512
# Crack pattern saved to inverted_crack_mask/2334.jpg
# 752 512 512
# Crack pattern saved to inverted_crack_mask/1989.jpg
# 753 512 512
# Crack pattern saved to inverted_crack_mask/2728.jpg
# 754 512 512
# Crack pattern saved to inverted_crack_mask/1361.jpg
# 755 512 512
# ...
# 2493 512 512
# Crack pattern saved to inverted_crack_mask/2169.jpg
# 2494 512 512
# Crack pattern saved to inverted_crack_mask/1776.jpg
# 2495 512 512
# Crack pattern saved to inverted_crack_mask/903.jpg
# 2496 512 512
# Crack pattern saved to inverted_crack_mask/1809.jpg
# 2497 512 512
# Crack pattern saved to inverted_crack_mask/1787.jpg
# 2498 512 512
# Crack pattern saved to inverted_crack_mask/795.jpg
# 2499 512 512
# Crack pattern saved to inverted_crack_mask/2325.jpg
# 2500 512 512
# Crack pattern saved to inverted_crack_mask/1714.jpg
# 2501 512 512
# Crack pattern saved to inverted_crack_mask/1230.jpg
# 2502 512 512
# Crack pattern saved to inverted_crack_mask/1665.jpg
# 2503 512 512
# Crack pattern saved to inverted_crack_mask/2234.jpg
# 2504 512 512
# Crack pattern saved to inverted_crack_mask/274.jpg
# 2505 512 512
# Crack pattern saved to inverted_crack_mask/2671.jpg
# 2506 512 512
# Crack pattern saved to inverted_crack_mask/686.jpg
# 2507 512 512
# Crack pattern saved to inverted_crack_mask/110.jpg
# 2508 512 512
# Crack pattern saved to inverted_crack_mask/976.jpg
# 2509 512 512
# Crack pattern saved to inverted_crack_mask/314.jpg
# 2510 512 512
# Crack pattern saved to inverted_crack_mask/1046.jpg
# 2511 512 512
# Crack pattern saved to inverted_crack_mask/1418.jpg
# 2512 512 512
# Crack pattern saved to inverted_crack_mask/1177.jpg
# 2513 512 512
# Crack pattern saved to inverted_crack_mask/1672.jpg
# 2514 512 512
# Crack pattern saved to inverted_crack_mask/447.jpg
# 2515 512 512
# Crack pattern saved to inverted_crack_mask/1446.jpg
# 2516 512 512
# Crack pattern saved to inverted_crack_mask/2228.jpg
# 2517 512 512
# Crack pattern saved to inverted_crack_mask/1876.jpg
# 2518 512 512
# Crack pattern saved to inverted_crack_mask/1403.jpg
# 2519 512 512
# Crack pattern saved to inverted_crack_mask/993.jpg
# 2520 512 512
# Crack pattern saved to inverted_crack_mask/2479.jpg
# 2521 512 512
# Crack pattern saved to inverted_crack_mask/2304.jpg
# 2522 512 512
# Crack pattern saved to inverted_crack_mask/1863.jpg
# 2523 512 512
# Crack pattern saved to inverted_crack_mask/1660.jpg
# 2524 512 512
# Crack pattern saved to inverted_crack_mask/301.jpg
# 2525 512 512
# Crack pattern saved to inverted_crack_mask/1998.jpg
# 2526 512 512
# Crack pattern saved to inverted_crack_mask/2434.jpg
# 2527 512 512
# Crack pattern saved to inverted_crack_mask/2080.jpg
# 2528 512 512
# Crack pattern saved to inverted_crack_mask/1087.jpg
# 2529 512 512
# Crack pattern saved to inverted_crack_mask/2471.jpg
# 2530 512 512
# Crack pattern saved to inverted_crack_mask/600.jpg
# 2531 512 512
# Crack pattern saved to inverted_crack_mask/770.jpg
# 2532 512 512
# Crack pattern saved to inverted_crack_mask/1079.jpg
# 2533 512 512
# Crack pattern saved to inverted_crack_mask/1277.jpg
# 2534 512 512
# Crack pattern saved to inverted_crack_mask/624.jpg
# 2535 512 512
# Crack pattern saved to inverted_crack_mask/2311.jpg
# 2536 512 512
# Crack pattern saved to inverted_crack_mask/2617.jpg
# 2537 512 512
# Crack pattern saved to inverted_crack_mask/896.jpg
# 2538 512 512
# Crack pattern saved to inverted_crack_mask/1302.jpg
# 2539 512 512
# Crack pattern saved to inverted_crack_mask/827.jpg
# 2540 512 512
# Crack pattern saved to inverted_crack_mask/2217.jpg
# 2541 512 512
# Crack pattern saved to inverted_crack_mask/644.jpg
# 2542 512 512
# Crack pattern saved to inverted_crack_mask/2730.jpg
# 2543 512 512
# Crack pattern saved to inverted_crack_mask/2152.jpg
# 2544 512 512
# Crack pattern saved to inverted_crack_mask/117.jpg
# 2545 512 512
# Crack pattern saved to inverted_crack_mask/262.jpg
# 2546 512 512
# Crack pattern saved to inverted_crack_mask/1243.jpg
# 2547 512 512
# Crack pattern saved to inverted_crack_mask/2142.jpg
# 2548 512 512
# Crack pattern saved to inverted_crack_mask/2072.jpg
# 2549 512 512
# Crack pattern saved to inverted_crack_mask/1463.jpg
# 2550 512 512
# Crack pattern saved to inverted_crack_mask/2253.jpg
# 2551 512 512
# Crack pattern saved to inverted_crack_mask/1451.jpg
# 2552 512 512
# Crack pattern saved to inverted_crack_mask/1306.jpg
# 2553 512 512
# Crack pattern saved to inverted_crack_mask/751.jpg
# 2554 512 512
# Crack pattern saved to inverted_crack_mask/1708.jpg
# 2555 512 512
# Crack pattern saved to inverted_crack_mask/971.jpg
# 2556 512 512
# Crack pattern saved to inverted_crack_mask/1151.jpg
# 2557 512 512
# Crack pattern saved to inverted_crack_mask/2524.jpg
# 2558 512 512
# Crack pattern saved to inverted_crack_mask/2535.jpg
# 2559 512 512
# Crack pattern saved to inverted_crack_mask/1483.jpg
# 2560 512 512
# Crack pattern saved to inverted_crack_mask/473.jpg
# 2561 512 512
# Crack pattern saved to inverted_crack_mask/2292.jpg
# 2562 512 512
# Crack pattern saved to inverted_crack_mask/1362.jpg
# 2563 512 512
# Crack pattern saved to inverted_crack_mask/1492.jpg
# 2564 512 512
# Crack pattern saved to inverted_crack_mask/2047.jpg
# 2565 512 512
# Crack pattern saved to inverted_crack_mask/1288.jpg
# 2566 512 512
# Crack pattern saved to inverted_crack_mask/2444.jpg
# 2567 512 512
# Crack pattern saved to inverted_crack_mask/951.jpg
# 2568 512 512
# Crack pattern saved to inverted_crack_mask/2351.jpg
# 2569 512 512
# Crack pattern saved to inverted_crack_mask/1821.jpg
# 2570 512 512
# Crack pattern saved to inverted_crack_mask/2306.jpg
# 2571 512 512
# Crack pattern saved to inverted_crack_mask/2254.jpg
# 2572 512 512
# Crack pattern saved to inverted_crack_mask/1638.jpg
# 2573 512 512
# Crack pattern saved to inverted_crack_mask/1388.jpg
# 2574 512 512
# Crack pattern saved to inverted_crack_mask/1663.jpg
# 2575 512 512
# Crack pattern saved to inverted_crack_mask/879.jpg
# 2576 512 512
# Crack pattern saved to inverted_crack_mask/1176.jpg
# 2577 512 512
# Crack pattern saved to inverted_crack_mask/2059.jpg
# 2578 512 512
# Crack pattern saved to inverted_crack_mask/2623.jpg
# 2579 512 512
# Crack pattern saved to inverted_crack_mask/1911.jpg
# 2580 512 512
# Crack pattern saved to inverted_crack_mask/2483.jpg
# 2581 512 512
# Crack pattern saved to inverted_crack_mask/278.jpg
# 2582 512 512
# Crack pattern saved to inverted_crack_mask/479.jpg
# 2583 512 512
# Crack pattern saved to inverted_crack_mask/2436.jpg
# 2584 512 512
# Crack pattern saved to inverted_crack_mask/1147.jpg
# 2585 512 512
# Crack pattern saved to inverted_crack_mask/468.jpg
# 2586 512 512
# Crack pattern saved to inverted_crack_mask/1798.jpg
# 2587 512 512
# Crack pattern saved to inverted_crack_mask/1106.jpg
# 2588 512 512
# Crack pattern saved to inverted_crack_mask/532.jpg
# 2589 512 512
# Crack pattern saved to inverted_crack_mask/511.jpg
# 2590 512 512
# Crack pattern saved to inverted_crack_mask/518.jpg
# 2591 512 512
# Crack pattern saved to inverted_crack_mask/2297.jpg
# 2592 512 512
# Crack pattern saved to inverted_crack_mask/1650.jpg
# 2593 512 512
# Crack pattern saved to inverted_crack_mask/1209.jpg
# 2594 512 512
# Crack pattern saved to inverted_crack_mask/1182.jpg
# 2595 512 512
# Crack pattern saved to inverted_crack_mask/1386.jpg
# 2596 512 512
# Crack pattern saved to inverted_crack_mask/1137.jpg
# 2597 512 512
# Crack pattern saved to inverted_crack_mask/1005.jpg
# 2598 512 512
# Crack pattern saved to inverted_crack_mask/859.jpg
# 2599 512 512
# Crack pattern saved to inverted_crack_mask/516.jpg
# 2600 512 512
# Crack pattern saved to inverted_crack_mask/2339.jpg
# 2601 512 512
# Crack pattern saved to inverted_crack_mask/1569.jpg
# 2602 512 512
# Crack pattern saved to inverted_crack_mask/2315.jpg
# 2603 512 512
# Crack pattern saved to inverted_crack_mask/2233.jpg
# 2604 512 512
# Crack pattern saved to inverted_crack_mask/1627.jpg
# 2605 512 512
# Crack pattern saved to inverted_crack_mask/51.jpg
# 2606 512 512
# Crack pattern saved to inverted_crack_mask/1560.jpg
# 2607 512 512
# Crack pattern saved to inverted_crack_mask/491.jpg
# 2608 512 512
# Crack pattern saved to inverted_crack_mask/75.jpg
# 2609 512 512
# Crack pattern saved to inverted_crack_mask/1770.jpg
# 2610 512 512
# Crack pattern saved to inverted_crack_mask/2225.jpg
# 2611 512 512
# Crack pattern saved to inverted_crack_mask/340.jpg
# 2612 512 512
# Crack pattern saved to inverted_crack_mask/651.jpg
# 2613 512 512
# Crack pattern saved to inverted_crack_mask/2650.jpg
# 2614 512 512
# Crack pattern saved to inverted_crack_mask/1730.jpg
# 2615 512 512
# Crack pattern saved to inverted_crack_mask/192.jpg
# 2616 512 512
# Crack pattern saved to inverted_crack_mask/825.jpg
# 2617 512 512
# Crack pattern saved to inverted_crack_mask/2084.jpg
# 2618 512 512
# Crack pattern saved to inverted_crack_mask/324.jpg
# 2619 512 512
# Crack pattern saved to inverted_crack_mask/2316.jpg
# 2620 512 512
# Crack pattern saved to inverted_crack_mask/1679.jpg
# 2621 512 512
# Crack pattern saved to inverted_crack_mask/1950.jpg
# 2622 512 512
# Crack pattern saved to inverted_crack_mask/2298.jpg
# 2623 512 512
# Crack pattern saved to inverted_crack_mask/2523.jpg
# 2624 512 512
# Crack pattern saved to inverted_crack_mask/747.jpg
# 2625 512 512
# Crack pattern saved to inverted_crack_mask/1552.jpg
# 2626 512 512
# Crack pattern saved to inverted_crack_mask/1837.jpg
# 2627 512 512
# Crack pattern saved to inverted_crack_mask/2295.jpg
# 2628 512 512
# Crack pattern saved to inverted_crack_mask/1536.jpg
# 2629 512 512
# Crack pattern saved to inverted_crack_mask/967.jpg
# 2630 512 512
# Crack pattern saved to inverted_crack_mask/1974.jpg
# 2631 512 512
# Crack pattern saved to inverted_crack_mask/1773.jpg
# 2632 512 512
# Crack pattern saved to inverted_crack_mask/1597.jpg
# 2633 512 512
# Crack pattern saved to inverted_crack_mask/1808.jpg
# 2634 512 512
# Crack pattern saved to inverted_crack_mask/1744.jpg
# 2635 512 512
# Crack pattern saved to inverted_crack_mask/2382.jpg
# 2636 512 512
# Crack pattern saved to inverted_crack_mask/626.jpg
# 2637 512 512
# Crack pattern saved to inverted_crack_mask/2040.jpg
# 2638 512 512
# Crack pattern saved to inverted_crack_mask/2042.jpg
# 2639 512 512
# Crack pattern saved to inverted_crack_mask/1135.jpg
# 2640 512 512
# Crack pattern saved to inverted_crack_mask/326.jpg
# 2641 512 512
# Crack pattern saved to inverted_crack_mask/1956.jpg
# 2642 512 512
# Crack pattern saved to inverted_crack_mask/355.jpg
# 2643 512 512
# Crack pattern saved to inverted_crack_mask/2173.jpg
# 2644 512 512
# Crack pattern saved to inverted_crack_mask/1123.jpg
# 2645 512 512
# Crack pattern saved to inverted_crack_mask/850.jpg
# 2646 512 512
# Crack pattern saved to inverted_crack_mask/1829.jpg
# 2647 512 512
# Crack pattern saved to inverted_crack_mask/2105.jpg
# 2648 512 512
# Crack pattern saved to inverted_crack_mask/325.jpg
# 2649 512 512
# Crack pattern saved to inverted_crack_mask/2371.jpg
# 2650 512 512
# Crack pattern saved to inverted_crack_mask/1245.jpg
# 2651 512 512
# Crack pattern saved to inverted_crack_mask/997.jpg
# 2652 512 512
# Crack pattern saved to inverted_crack_mask/1114.jpg
# 2653 512 512
# Crack pattern saved to inverted_crack_mask/842.jpg
# 2654 512 512
# Crack pattern saved to inverted_crack_mask/2154.jpg
# 2655 512 512
# Crack pattern saved to inverted_crack_mask/2398.jpg
# 2656 512 512
# Crack pattern saved to inverted_crack_mask/1615.jpg
# 2657 512 512
# Crack pattern saved to inverted_crack_mask/1434.jpg
# 2658 512 512
# Crack pattern saved to inverted_crack_mask/2275.jpg
# 2659 512 512
# Crack pattern saved to inverted_crack_mask/1065.jpg
# 2660 512 512
# Crack pattern saved to inverted_crack_mask/1681.jpg
# 2661 512 512
# Crack pattern saved to inverted_crack_mask/1226.jpg
# 2662 512 512
# Crack pattern saved to inverted_crack_mask/2691.jpg
# 2663 512 512
# Crack pattern saved to inverted_crack_mask/246.jpg
# 2664 512 512
# Crack pattern saved to inverted_crack_mask/294.jpg
# 2665 512 512
# Crack pattern saved to inverted_crack_mask/579.jpg
# 2666 512 512
# Crack pattern saved to inverted_crack_mask/2255.jpg
# 2667 512 512
# Crack pattern saved to inverted_crack_mask/1839.jpg
# 2668 512 512
# Crack pattern saved to inverted_crack_mask/574.jpg
# 2669 512 512
# Crack pattern saved to inverted_crack_mask/269.jpg
# 2670 512 512
# Crack pattern saved to inverted_crack_mask/2561.jpg
# 2671 512 512
# Crack pattern saved to inverted_crack_mask/163.jpg
# 2672 512 512
# Crack pattern saved to inverted_crack_mask/2465.jpg
# 2673 512 512
# Crack pattern saved to inverted_crack_mask/2615.jpg
# 2674 512 512
# Crack pattern saved to inverted_crack_mask/1139.jpg
# 2675 512 512
# Crack pattern saved to inverted_crack_mask/2051.jpg
# 2676 512 512
# Crack pattern saved to inverted_crack_mask/1162.jpg
# 2677 512 512
# Crack pattern saved to inverted_crack_mask/1957.jpg
# 2678 512 512
# Crack pattern saved to inverted_crack_mask/606.jpg
# 2679 512 512
# Crack pattern saved to inverted_crack_mask/243.jpg
# 2680 512 512
# Crack pattern saved to inverted_crack_mask/317.jpg
# 2681 512 512
# Crack pattern saved to inverted_crack_mask/2324.jpg
# 2682 512 512
# Crack pattern saved to inverted_crack_mask/1908.jpg
# 2683 512 512
# Crack pattern saved to inverted_crack_mask/2207.jpg
# 2684 512 512
# Crack pattern saved to inverted_crack_mask/1747.jpg
# 2685 512 512
# Crack pattern saved to inverted_crack_mask/1824.jpg
# 2686 512 512
# Crack pattern saved to inverted_crack_mask/2007.jpg
# 2687 512 512
# Crack pattern saved to inverted_crack_mask/2014.jpg
# 2688 512 512
# Crack pattern saved to inverted_crack_mask/451.jpg
# 2689 512 512
# Crack pattern saved to inverted_crack_mask/2313.jpg
# 2690 512 512
# Crack pattern saved to inverted_crack_mask/1272.jpg
# 2691 512 512
# Crack pattern saved to inverted_crack_mask/1380.jpg
# 2692 512 512
# Crack pattern saved to inverted_crack_mask/521.jpg
# 2693 512 512
# Crack pattern saved to inverted_crack_mask/2196.jpg
# 2694 512 512
# Crack pattern saved to inverted_crack_mask/2328.jpg
# 2695 512 512
# Crack pattern saved to inverted_crack_mask/162.jpg
# 2696 512 512
# Crack pattern saved to inverted_crack_mask/2713.jpg
# 2697 512 512
# Crack pattern saved to inverted_crack_mask/2511.jpg
# 2698 512 512
# Crack pattern saved to inverted_crack_mask/1582.jpg
# 2699 512 512
# Crack pattern saved to inverted_crack_mask/2541.jpg
# 2700 512 512
# Crack pattern saved to inverted_crack_mask/748.jpg
# 2701 512 512
# Crack pattern saved to inverted_crack_mask/1940.jpg
# 2702 512 512
# Crack pattern saved to inverted_crack_mask/1588.jpg
# 2703 512 512
# Crack pattern saved to inverted_crack_mask/1768.jpg
# 2704 512 512
# Crack pattern saved to inverted_crack_mask/659.jpg
# 2705 512 512
# Crack pattern saved to inverted_crack_mask/909.jpg
# 2706 512 512
# Crack pattern saved to inverted_crack_mask/1563.jpg
# 2707 512 512
# Crack pattern saved to inverted_crack_mask/2626.jpg
# 2708 512 512
# Crack pattern saved to inverted_crack_mask/1507.jpg
# 2709 512 512
# Crack pattern saved to inverted_crack_mask/1260.jpg
# 2710 512 512
# Crack pattern saved to inverted_crack_mask/834.jpg
# 2711 512 512
# Crack pattern saved to inverted_crack_mask/1258.jpg
# 2712 512 512
# Crack pattern saved to inverted_crack_mask/1183.jpg
# 2713 512 512
# Crack pattern saved to inverted_crack_mask/2293.jpg
# 2714 512 512
# Crack pattern saved to inverted_crack_mask/773.jpg
# 2715 512 512
# Crack pattern saved to inverted_crack_mask/667.jpg
# 2716 512 512
# Crack pattern saved to inverted_crack_mask/522.jpg
# 2717 512 512
# Crack pattern saved to inverted_crack_mask/1105.jpg
# 2718 512 512
# Crack pattern saved to inverted_crack_mask/478.jpg
# 2719 512 512
# Crack pattern saved to inverted_crack_mask/709.jpg
# 2720 512 512
# Crack pattern saved to inverted_crack_mask/309.jpg
# 2721 512 512
# Crack pattern saved to inverted_crack_mask/392.jpg
# 2722 512 512
# Crack pattern saved to inverted_crack_mask/1645.jpg
# 2723 512 512
# Crack pattern saved to inverted_crack_mask/891.jpg
# 2724 512 512
# Crack pattern saved to inverted_crack_mask/329.jpg
# 2725 512 512
# Crack pattern saved to inverted_crack_mask/1720.jpg
# 2726 512 512
# Crack pattern saved to inverted_crack_mask/358.jpg
# 2727 512 512
# Crack pattern saved to inverted_crack_mask/234.jpg
# 2728 512 512
# Crack pattern saved to inverted_crack_mask/2655.jpg
# 2729 512 512
# Crack pattern saved to inverted_crack_mask/1089.jpg
# 2730 512 512
# Crack pattern saved to inverted_crack_mask/1098.jpg
# 2731 512 512
# Crack pattern saved to inverted_crack_mask/1795.jpg
# 2732 512 512
# Crack pattern saved to inverted_crack_mask/1915.jpg
# 2733 512 512
# Crack pattern saved to inverted_crack_mask/2579.jpg
# 2734 512 512
# Crack pattern saved to inverted_crack_mask/1647.jpg
# 2735 512 512
# Crack pattern saved to inverted_crack_mask/1366.jpg
# 2736 512 512
# Crack pattern saved to inverted_crack_mask/534.jpg
# 2737 512 512
# Crack pattern saved to inverted_crack_mask/1228.jpg
# 2738 512 512
# Crack pattern saved to inverted_crack_mask/588.jpg
# 2739 512 512
# Crack pattern saved to inverted_crack_mask/1657.jpg
# 2740 512 512

# %%
#apply the crack mask seperatly, since it needs different alpha values.
damaged_images = []
for i in range(len(images)):
    image_rgb = images[i]  # Shape (height, width, 3)
    crack_rgb = cracks[i][:, :, :3]  # Extract RGB part of cracks (Shape: height, width, 3)
    
    # Extract alpha channel from cracks (Shape: height, width, 1)
    crack_alpha = cracks[i][:, :, 3]  
    
    # Convert alpha to a range of 0 to 1 for blending (alpha/255)
    crack_alpha_normalized = crack_alpha.astype(np.float32) / 255.0
    alpha_value = np.random.randint(5,25)
    alpha_blend = alpha_value / 100.0
    
    # Perform the blending only where crack_alpha is non-zero
    blended_rgb = image_rgb * (1 - alpha_blend * crack_alpha_normalized[..., None]) + crack_rgb * alpha_blend * crack_alpha_normalized[..., None]
    
    # Clip values to stay within [0, 255] and convert back to uint8
    blended_rgb = np.clip(blended_rgb, 0, 255).astype(np.uint8)

    # Stack the blended RGB with the original alpha channel to create the final RGBA image
    blended = np.dstack((blended_rgb, crack_alpha))  # Add alpha channel back
    
    # Append to the list of damaged images
    damaged_images.append(blended)
    
    # Save the blended image (RGBA)
    cv2.imwrite(f"damaged_paintings/{file_names[i]}", blended)

    
    #invert the crack_map for later
    cv2.imwrite("crack_mask/"+file_names[i], 255-cracks[i])
    
print("done")
# Out:
# done

# %%
#next we wanna add some other damages. we just add them to the image and the mask.
folder_path = "crack_mask/"
masks, file_names = load_images(folder_path,grayscale=True)
damage_functions = [generate_scratches,generate_rough_scratches,generate_horizontal_damage,generate_abrasions]
for i in range(len(masks)):
    mask = masks[i]
    height,width = mask.shape[:2]
    overlay = np.zeros((height, width, 4), dtype=np.uint8)
    num_functions = np.random.randint(1,4)
    selected_functions = np.random.choice(damage_functions, num_functions, replace=False)
    for func in selected_functions:
        mask,overlay = func(mask,overlay)
    cv2.imwrite("final_mask/"+file_names[i],mask)
    
    image = damaged_images[i]
    image = image[:,:,:3]
    overlay_rgb = overlay[:,:,:3]
    overlay_alpha = overlay[:,:,3]
    alpha_normalized = overlay_alpha.astype(float) / 255.0
    blended_image = image.astype(float) * (1 - alpha_normalized[:, :, None]) + overlay_rgb.astype(float) * alpha_normalized[:, :, None]
    cv2.imwrite("final_paintings/"+file_names[i],blended_image)
plt.imshow(overlay)
plt.show()
# Out:
# Loaded 2759 images from crack_mask/
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 15
#      12     mask,overlay = func(mask,overlay)
#      13 cv2.imwrite("final_mask/"+file_names[i],mask)
# ---> 15 image = damaged_images[i]
#      16 image = image[:,:,:3]
#      17 overlay_rgb = overlay[:,:,:3]
#
# IndexError: list index out of range
